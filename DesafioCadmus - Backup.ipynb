# %%
import requests
import json
import pandas as pd
from datetime import datetime, timedelta
from pandas.io.json import json_normalize

# %%
api_youtube = 'https://charts.youtube.com/youtubei/v1/browse?alt=json&key=AIzaSyCzEW7JUJdSql0-2V4tHUb6laYm4iAE_dM'
headers = {'Content-Type: application/json'}
params = {
    
    "context": {
        "client": {
            "clientName": "WEB_MUSIC_ANALYTICS",
            "clientVersion": "0.2",
            "hl": "pt",
            "gl": "BR",
            "experimentIds": [],
            "experimentsToken": "",
            "theme": "MUSIC"
        },
        "capabilities": {},
        "request": {
            "internalExperimentFlags": []
        }
    },
    "browseId": "FEmusic_analytics_charts_home",
    "query": "chart_params_type=WEEK&perspective=CHART&flags=viral_video_chart&selected_chart=TRACKS&chart_params_id=weekly%3A20190111%3A20190117%3Abr"
}

# %%
req = requests.post(api_youtube, json=params)

# %%
req
# Out:
# <Response [200]>

# %%
dados = req.json()
artistas = dados["contents"]["sectionListRenderer"]["contents"]

# %%
# from pandas.io.json import json_normalize

users = json_normalize(dados["contents"]["sectionListRenderer"]["contents"])

# users.keys()
# Out:
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\1726960219.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   users = json_normalize(dados["contents"]["sectionListRenderer"]["contents"])

# %%
tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
                         sep='_',
                         record_path=['musicAnalyticsSectionRenderer','content','trackTypes','trackViews'])

tracks.head(5)
# Out:
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2106755952.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
#               id                                               name viewCount  \
# 0  Y:AgWUtFtSviE                                            Jenifer  35236567
# 1  Y:68DzEwBC2Cw                    Notificação Preferida (Ao Vivo)  13390074
# 2  Y:j47F_UFQHm0                                       Quem Me Dera  13095491
# 3  Y:lwp2e0tFtZM  Hoje Eu Vou Parar Na Gaiola (feat. DJ Rennan d...  11856586
# 4  Y:sSoVIcYmkPY                                   Agora é Tudo Meu  11647694
#
#   encryptedVideoId                                            artists  \
# 0      D2rG7pXd2LY  [{'kgMid': '/g/11h0d3dnyr', 'name': 'Gabriel D...
# 1      rYKOuKaWEjg  [{'kgMid': '/g/11c602sm4t', 'name': 'Zé Neto &...
# 2      BRw8e5OGnrI  [{'kgMid': '/g/11c54ch2hn', 'name': 'Márcia Fe...
# 3      1ppPuobqt-g  [{'kgMid': '/g/11b6_sq0s2', 'name': 'Mc Livinh...
# 4      1MTsqRU-4LY  [{'kgMid': '/g/11b60z06t1', 'name': 'DENNIS'},...
#
#    isVisible atvExternalVideoId  \
# 0       True        W10ssxG3q9E
# 1       True        vFW8c0N_nLs
# 2       True        8-J6pdXOJhU
# 3       True        R7WyzglbOrI
# 4       True        lY-DINmUpcI
#
#                                 thumbnail_thumbnails  \
# 0  [{'url': 'https://i.ytimg.com/vi/D2rG7pXd2LY/d...
# 1  [{'url': 'https://i.ytimg.com/vi/rYKOuKaWEjg/d...
# 2  [{'url': 'https://i.ytimg.com/vi/BRw8e5OGnrI/d...
# 3  [{'url': 'https://i.ytimg.com/vi/1ppPuobqt-g/d...
# 4  [{'url': 'https://i.ytimg.com/vi/1MTsqRU-4LY/d...
#
#    chartEntryMetadata_currentPosition  chartEntryMetadata_previousPosition  \
# 0                                   1                                  1.0
# 1                                   2                                  9.0
# 2                                   3                                  3.0
# 3                                   4                                  2.0
# 4                                   5                                  4.0
#
#    chartEntryMetadata_percentViewsChange  chartEntryMetadata_periodsOnChart  \
# 0                               0.748762                                 13
# 1                               0.376116                                 29
# 2                               0.145365                                 14
# 3                               0.019664                                  9
# 4                               0.077879                                  6
#
#    releaseDate_year  releaseDate_month  releaseDate_day
# 0              2018                  9               14
# 1              2018                  5               18
# 2              2018                 10               15
# 3              2018                 10                9
# 4              2018                 12                5

# %%
artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
                         sep='_',
                         meta=[['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','id']])
artistas.head(5)
# Out:
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\3561707104.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
#            kgMid                 name  \
# 0  /g/11h0d3dnyr        Gabriel Diniz
# 1  /g/11c602sm4t  Zé Neto & Cristiano
# 2  /g/11c54ch2hn       Márcia Fellipe
# 3            NaN          Jerry Smith
# 4  /g/11b6_sq0s2           Mc Livinho
#
#   musicAnalyticsSectionRenderer_content_trackTypes_trackViews_id
# 0                                      Y:AgWUtFtSviE
# 1                                      Y:68DzEwBC2Cw
# 2                                      Y:j47F_UFQHm0
# 3                                      Y:j47F_UFQHm0
# 4                                      Y:lwp2e0tFtZM

# %%
artistas.to_csv('artistas.csv')
tracks.to_csv('tracks.csv')

# %%
# pip install google-api-python-client

# %%
# Função para obter dados semanais do youtube charts

import requests
import json
import pandas as pd
from datetime import datetime, timedelta
from pandas.io.json import json_normalize

# Formatação de data e inicialização dos arquivos de saída.
# A função faz um loop de cada semana, pega as 100 tracks mais tocadas e concatena no arquivo de saída.
# Ao final do loop o arquivo de saída é salvo em um .csv para ser consumido no Tableau.

def get_youtube_charts_data(start_date='20190104', end_date='20230602'):
    date_format = '%Y%m%d'
    current_date = datetime.strptime(start_date, date_format)
    end_date = datetime.strptime(end_date, date_format)
    file_artistas = []
    file_tracks = []

    while current_date <= end_date:
        # Formatação de datas de início e fim da semana, a serem inseridas na URL
        formatted_date = current_date.strftime(date_format)
        week_date = (current_date + timedelta(days=6)).strftime(date_format)
        
        #Parametros da requisição. Os valores de data em 'query' variam conforme a semana selecionada.
        params = {
            "context": {
                "client": {
                    "clientName": "WEB_MUSIC_ANALYTICS",
                    "clientVersion": "0.2",
                    "hl": "pt",
                    "gl": "BR",
                    "experimentIds": [],
                    "experimentsToken": "",
                    "theme": "MUSIC"
                },
                "capabilities": {},
                "request": {
                    "internalExperimentFlags": []
                }
            },
            "browseId": "FEmusic_analytics_charts_home",
            "query": f"chart_params_type=WEEK&perspective=CHART&flags=viral_video_chart&selected_chart=TRACKS&chart_params_id=weekly%3A{formatted_date}%3A{week_date}%3Abr"
        }
        
        # Exceução da requisição com os parâmetros acima e obtenção do json 
        req = requests.post(api_youtube, json=params)
        dados = req.json()

        # O json de saída é aninhado em vários níveis, é necessário 'descer' pelas keys para fazer a normalização apenas da parte de Tracks ('trackviews')
        tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
                         sep='_',
                         record_path=['musicAnalyticsSectionRenderer','content','trackTypes','trackViews']) 

        # Criação de coluna de data para indicar qual a semana de entrada do registro
        tracks = tracks.assign(data_inicio=current_date)

        # A mesma lógica se aplica para obter os dados de nomes dos artistas, que estão em um nível abaixo no json
        artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
                         sep='_',
                         meta=[['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','id']])

        artistas = artistas.assign(data_inicio=current_date)

        # Final da extração da semana atual, soma-se 7 dias, armazena-se os dados extraídos e avança para a próxima semana no loop
        current_date += timedelta(days=7)

        file_tracks.append(tracks)
        file_artistas.append(artistas)
    
    # Ao final do loop, é feita a concatenação dos dados armazenados de cada semana em dataframes únicos 
    df_artistas = pd.concat(file_artistas)
    df_tracks = pd.concat(file_tracks)

    # Os dataframes são salvos em formato .csv com indicação do início e fim da extração
    end_date = end_date.strftime(date_format) 
    
    artistas_filename = f'artistas_data_{start_date}_{end_date}.csv'
    tracks_filename = f'tracks_data_{start_date}_{end_date}.csv'

    df_artistas.to_csv(artistas_filename)        
    df_tracks.to_csv(tracks_filename)     
    
    return df_artistas, df_tracks   

tracks_data = get_youtube_charts_data() 
tracks_data
# Out:
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
# ...
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   tracks = json_normalize(dados["contents"]["sectionListRenderer"]["contents"],
# C:\Users\rapha\AppData\Local\Temp\ipykernel_4296\2141381167.py:59: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artistas = json_normalize(dados['contents']['sectionListRenderer']['contents'],['musicAnalyticsSectionRenderer','content','trackTypes','trackViews','artists'],
# (             kgMid              name  \
#  0    /g/11h0d3dnyr     Gabriel Diniz
#  1    /g/11b6_sq0s2        Mc Livinho
#  2    /g/11c54ch2hn    Márcia Fellipe
#  3              NaN       Jerry Smith
#  4    /g/11b60z06t1            DENNIS
#  ..             ...               ...
#  191  /g/11f7j3kh4y             Dj GM
#  192  /g/11frvp2c6j           MC Luck
#  193  /g/11bt_bgy1p           MC Bill
#  194  /g/11jp2p56lt  Nadson O Ferinha
#  195  /g/11jcn2j3bw     Felipe Amorim
#
#      musicAnalyticsSectionRenderer_content_trackTypes_trackViews_id data_inicio
#  0                                        Y:AgWUtFtSviE              2019-01-04
#  1                                        Y:lwp2e0tFtZM              2019-01-04
#  2                                        Y:j47F_UFQHm0              2019-01-04
#  3                                        Y:j47F_UFQHm0              2019-01-04
#  4                                        Y:sSoVIcYmkPY              2019-01-04
#  ..                                                 ...                     ...
#  191                                      G:BD9_lz6_jKs              2023-06-02
#  192                                      G:BD9_lz6_jKs              2023-06-02
#  193                                      G:BD9_lz6_jKs              2023-06-02
#  194                                      G:eMzETiGRChQ              2023-06-02
#  195                                      G:VPO3FB2F4sE              2023-06-02
#
#  [41404 rows x 4 columns],
#                 id                                               name  \
#  0   Y:AgWUtFtSviE                                            Jenifer
#  1   Y:lwp2e0tFtZM  Hoje Eu Vou Parar Na Gaiola (feat. DJ Rennan d...
#  2   Y:j47F_UFQHm0                                       Quem Me Dera
#  3   Y:sSoVIcYmkPY                                   Agora é Tudo Meu
#  4   Y:KjM62Bvp744                                   Parado no Bailão
#  ..            ...                                                ...
#  95  G:JN17h0LGP7I                                          Doutora 3
#  96  G:mkH9PuKNxU4            Feirão dos 23 (feat. Babidi & LB Único)
#  97  G:BD9_lz6_jKs                                      Set Do Manoel
#  98  G:eMzETiGRChQ                                            Cuidado
#  99  G:VPO3FB2F4sE                                  Coisas Que Eu Sei
#
#     viewCount encryptedVideoId  \
#  0   20149435      D2rG7pXd2LY
#  1   11627940      1ppPuobqt-g
#  2   11433469      BRw8e5OGnrI
#  3   10806125      1MTsqRU-4LY
#  4   10200638      upCptHeThio
#  ..       ...              ...
#  95   1630980      6UQHIQpBw6w
#  96   1625699      0yPQnBG0hzQ
#  97   1622588      Cn_ltkG_QpA
#  98   1618174      HIkJCmffMp8
#  99   1615566      QdWAkRK3HOk
#
#                                                artists  isVisible  \
#  0   [{'kgMid': '/g/11h0d3dnyr', 'name': 'Gabriel D...       True
#  1   [{'kgMid': '/g/11b6_sq0s2', 'name': 'Mc Livinh...       True
#  2   [{'kgMid': '/g/11c54ch2hn', 'name': 'Márcia Fe...       True
#  3   [{'kgMid': '/g/11b60z06t1', 'name': 'DENNIS'},...       True
#  4   [{'kgMid': '/g/11f9w6dy53', 'name': 'MC L da V...       True
#  ..                                                ...        ...
#  95  [{'kgMid': '/g/11h4dklcgj', 'name': 'Mc Kevin'...       True
#  96  [{'kgMid': '/g/11q47wcmkx', 'name': 'Raflow'},...       True
#  97  [{'kgMid': '/g/11c5qt3vhg', 'name': 'MC Lipi '...       True
#  98  [{'kgMid': '/g/11jp2p56lt', 'name': 'Nadson O ...       True
#  99  [{'kgMid': '/g/11jcn2j3bw', 'name': 'Felipe Am...       True
#
#     atvExternalVideoId                               thumbnail_thumbnails  \
#  0         W10ssxG3q9E  [{'url': 'https://i.ytimg.com/vi/D2rG7pXd2LY/d...
#  1         R7WyzglbOrI  [{'url': 'https://i.ytimg.com/vi/1ppPuobqt-g/d...
#  2         8-J6pdXOJhU  [{'url': 'https://i.ytimg.com/vi/BRw8e5OGnrI/d...
#  3         lY-DINmUpcI  [{'url': 'https://i.ytimg.com/vi/1MTsqRU-4LY/d...
#  4         7a0oiSnCWww  [{'url': 'https://i.ytimg.com/vi/upCptHeThio/d...
#  ..                ...                                                ...
#  95        kibsf-uvN-s  [{'url': 'https://i.ytimg.com/vi/6UQHIQpBw6w/d...
#  96        AEJdzyrKiEc  [{'url': 'https://i.ytimg.com/vi/0yPQnBG0hzQ/d...
#  97        1pch2JsTXZQ  [{'url': 'https://i.ytimg.com/vi/Cn_ltkG_QpA/d...
#  98        PRSvU7FpgrA  [{'url': 'https://i.ytimg.com/vi/HIkJCmffMp8/d...
#  99        z_zR_CYMyNo  [{'url': 'https://i.ytimg.com/vi/QdWAkRK3HOk/d...
#
#      chartEntryMetadata_currentPosition  chartEntryMetadata_previousPosition  \
#  0                                    1                                  9.0
#  1                                    2                                  1.0
#  2                                    3                                  4.0
#  3                                    4                                  6.0
#  4                                    5                                  2.0
#  ..                                 ...                                  ...
#  95                                  96                                  NaN
#  96                                  97                                  NaN
#  97                                  98                                 97.0
#  98                                  99                                 74.0
#  99                                 100                                  NaN
#
#      chartEntryMetadata_percentViewsChange  chartEntryMetadata_periodsOnChart  \
#  0                                0.960757                                 12
#  1                               -0.206459                                  8
#  2                               -0.137983                                 13
#  3                                0.016540                                  5
#  4                               -0.275039                                 11
#  ..                                    ...                                ...
#  95                                    NaN                                 28
#  96                                    NaN                                  1
#  97                               0.033625                                  3
#  98                              -0.186106                                  2
#  99                                    NaN                                  1
#
#      releaseDate_year  releaseDate_month  releaseDate_day data_inicio
#  0             2018.0                9.0             14.0  2019-01-04
#  1             2018.0               10.0              9.0  2019-01-04
#  2             2018.0               10.0             15.0  2019-01-04
#  3             2018.0               12.0              5.0  2019-01-04
#  4             2018.0                7.0             23.0  2019-01-04
#  ..               ...                ...              ...         ...
#  95            2021.0                3.0             30.0  2023-06-02
#  96            2023.0                4.0             27.0  2023-06-02
#  97            2023.0                4.0             19.0  2023-06-02
#  98            2023.0                4.0             29.0  2023-06-02
#  99            2023.0                4.0              6.0  2023-06-02
#
#  [23100 rows x 16 columns])
